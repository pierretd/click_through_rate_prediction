# %% [markdown]
# # Avazu CTR Prediction- Boosting Models

# %% [markdown]
# The most perfomant boosting model was XGboost with kfold cross validation scoring 0.744895 AUC.

# %% [markdown]
# ### Logistic Regression

# %%
plt.figure(figsize=(12,6))
plt.plot(fpr, tpr, color='red', lw=2)
plt.plot([0, 1], [0, 1], color='navy', lw=1, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Linear Regression ROC Curve')
plt.show()

# %%
from sklearn.metrics import roc_auc_score
print("The ROC AUC is : " + str(roc_auc_score(ytest, soft[:,1])))
# Out:
# The ROC AUC is : 0.693444753207521

# %%
lr_report = print(str(classification_report(ytest, hard)))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.84      0.99      0.91      7517
#            1       0.59      0.08      0.14      1582
#
#    micro avg       0.83      0.83      0.83      9099
#    macro avg       0.71      0.53      0.52      9099
# weighted avg       0.79      0.83      0.77      9099

# %% [markdown]
# ### Confusion Matrix

# %%
plot_confusion_matrix(cm,['No Click','Click'],normalize=True)
# Out:
# Normalized confusion matrix
# [[0.98882533 0.01117467]
#  [0.92288243 0.07711757]]

# %%
from sklearn.metrics import precision_recall_curve
import matplotlib.pyplot as plt

precision, recall, _ = precision_recall_curve(ytest, predictions)

plt.step(recall, precision, color='b', alpha=0.2,
         where='post')
plt.fill_between(recall, precision, step='post', alpha=0.2,
                 color='b')

plt.xlabel('Recall')
plt.ylabel('Precision')
plt.ylim([0.0, 1.05])
plt.xlim([0.0, 1.0])
plt.title('2-class Precision-Recall curve: AP={0:0.2f}'.format(
          average_precision))
# Out:
# Text(0.5,1,'2-class Precision-Recall curve: AP=0.21')

# %% [markdown]
# ### Gradient Boosting

# %%
plt.figure(figsize=(12,6))
plt.plot(fpr, tpr, color='red', lw=2)
plt.plot([0, 1], [0, 1], color='navy', lw=1, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Gradient Boosting ROC Curve')
plt.show()

# %%
print("The ROC AUC is : " + str(roc_auc_score(ytest, soft[:,1])))
# Out:
# The ROC AUC is : 0.5832826125089914

# %%
gb1_report = print(str(classification_report(ytest, hard)))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.83      0.90      0.86      7517
#            1       0.20      0.12      0.15      1582
#
#    micro avg       0.77      0.77      0.77      9099
#    macro avg       0.52      0.51      0.51      9099
# weighted avg       0.72      0.77      0.74      9099

# %%
plot_confusion_matrix(cm,['No Click','Click'],normalize=True)
# Out:
# Normalized confusion matrix
# [[0.90049222 0.09950778]
#  [0.87863464 0.12136536]]

# %%
from sklearn.metrics import precision_recall_curve
import matplotlib.pyplot as plt

precision, recall, _ = precision_recall_curve(ytest, predictions)

plt.step(recall, precision, color='b', alpha=0.2,
         where='post')
plt.fill_between(recall, precision, step='post', alpha=0.2,
                 color='b')

plt.xlabel('Recall')
plt.ylabel('Precision')
plt.ylim([0.0, 1.05])
plt.xlim([0.0, 1.0])
plt.title('2-class Precision-Recall curve: AP={0:0.2f}'.format(
          average_precision))
# Out:
# Text(0.5,1,'2-class Precision-Recall curve: AP=0.18')

# %%
from sklearn.ensemble import GradientBoostingClassifier
gb = GradientBoostingClassifier(n_estimators=50, learning_rate = 0.8, verbose=False,) 
gb.fit(Xtrain, ytrain)
# Out:
# GradientBoostingClassifier(criterion='friedman_mse', init=None,
#               learning_rate=0.8, loss='deviance', max_depth=3,
#               max_features=None, max_leaf_nodes=None,
#               min_impurity_decrease=0.0, min_impurity_split=None,
#               min_samples_leaf=1, min_samples_split=2,
#               min_weight_fraction_leaf=0.0, n_estimators=50,
#               n_iter_no_change=None, presort='auto', random_state=None,
#               subsample=1.0, tol=0.0001, validation_fraction=0.1,
#               verbose=False, warm_start=False)

# %%
plt.figure(figsize=(12,6))
plt.plot(fpr, tpr, color='red', lw=2)
plt.plot([0, 1], [0, 1], color='navy', lw=1, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Gradient Boosting ROC Curve')
plt.show()

# %%
hard = gb.predict(Xtest)
soft = gb.predict_proba(Xtest)
print("The ROC AUC is : " + str(roc_auc_score(ytest, soft[:,1])))
# Out:
# The ROC AUC is : 0.5816284605295002

# %%
gb2_report = print(str(classification_report(ytest, hard)))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.83      0.90      0.86      7517
#            1       0.20      0.12      0.15      1582
#
#    micro avg       0.76      0.76      0.76      9099
#    macro avg       0.52      0.51      0.51      9099
# weighted avg       0.72      0.76      0.74      9099

# %%
plot_confusion_matrix(cm,['No Click','Click'],normalize=True)
# Out:
# Normalized confusion matrix
# [[0.90022615 0.09977385]
#  [0.87863464 0.12136536]]

# %%
from sklearn.metrics import precision_recall_curve
import matplotlib.pyplot as plt

precision, recall, _ = precision_recall_curve(ytest, predictions)

plt.step(recall, precision, color='b', alpha=0.2,
         where='post')
plt.fill_between(recall, precision, step='post', alpha=0.2,
                 color='b')

plt.xlabel('Recall')
plt.ylabel('Precision')
plt.ylim([0.0, 1.05])
plt.xlim([0.0, 1.0])
plt.title('2-class Precision-Recall curve: AP={0:0.2f}'.format(
          average_precision))
# Out:
# Text(0.5,1,'2-class Precision-Recall curve: AP=0.18')
